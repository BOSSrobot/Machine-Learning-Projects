# %% [markdown]
# To test ai use https://pypi.org/project/selenium/ to get from https://ultimate-t3.herokuapp.com/local-game

# %% [markdown]
# GPU CREDITS!!!
#
# https://cloud.google.com/free/
#
# https://education.github.com/pack/
#
# https://azure.microsoft.com/en-in/free/students/
#
# List of them
#
# https://github.com/binga/cloud-gpus

# %% [markdown]
# research this
# https://github.com/zszazi/Deep-learning-in-cloud

# %% [markdown]
# Eric's connect 4 ai and notes:
#
# lol I exploited a feature of the website that uses the url as input. yeah just some digging around in the source code should get you what you need

# %% [markdown]
# ![image.png](attachment:image.png)
